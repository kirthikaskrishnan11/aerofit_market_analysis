# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Problem Statement:**
# Analysis of characteristics of targetted audience of the Aerofit company by analysing the data of the customers who purchased the tredmill from Aerofit. The analysis comprises the identification of the target customers' characteristics by conducting non-graphical and visual analysis on the provided dataset. Product purchased,age, gender, fitness, income level and usage pattern will be mostly analysed to get the apt customer profile and to provide necessary business insights and recommendation in order to enhance the business of Aerofit.

# %%
df=pd.read_csv('Business case_aerofit_treadmill.txt')

# %%
df.shape
# Out:
# (180, 9)

# %%
df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   KP281   18    Male         14        Single      3        4   29562    112
# 1   KP281   19    Male         15        Single      2        3   31836     75
# 2   KP281   19  Female         14     Partnered      4        3   30699     66
# 3   KP281   19    Male         12        Single      3        3   32973     85
# 4   KP281   20    Male         13     Partnered      4        2   35247     47

# %% [markdown]
# Insight:
# *   Dataset has data of 180 customers from the past three months
# *   It describes the customers' age, gender, education, marital status, usage pattern, the self-rated fitness, Income level and the average number of miles that the customer expected to walk in each week

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %% [markdown]
# *   There are no missing/null values in the dataset
# *   Product, gender and marital status are the columns with a categorical data
# *   Rest of the columns are having numerical data

# %%
df['Product'].astype('category')
df['Gender'].astype('category')
df['MaritalStatus'].astype('category')
df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   KP281   18    Male         14        Single      3        4   29562    112
# 1   KP281   19    Male         15        Single      2        3   31836     75
# 2   KP281   19  Female         14     Partnered      4        3   30699     66
# 3   KP281   19    Male         12        Single      3        3   32973     85
# 4   KP281   20    Male         13     Partnered      4        2   35247     47

# %%
df.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %% [markdown]
# Insights:
# *   Statistical analysis of the dataset in done.
# *   Count, mean, standard deviation, minimum, median, 25%, 75% and maximum  values corresponding to each numerical columns have been calculated for all the products together.
# * There are more positive outliers for the Age, Fitness, Income and Miles columns
# * Negative outliers will be there for the Education column.

# %%
df.drop_duplicates()
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 1     KP281   19    Male         15        Single      2        3   31836
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 3     KP281   19    Male         12        Single      3        3   32973
# 4     KP281   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   KP781   40    Male         21        Single      6        5   83416
# 176   KP781   42    Male         18        Single      5        4   89641
# 177   KP781   45    Male         16        Single      5        5   90886
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 179   KP781   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
df['Product'].value_counts(normalize=True)
# Out:
# Product
# KP281    0.444444
# KP481    0.333333
# KP781    0.222222
# Name: proportion, dtype: float64

# %% [markdown]
# *   KP281 is the most purchased item in the last three months and KP781 is the least purchased one.
# *   Probability id higher for purchasing the KP281 model as comapred to rest of the models
# *   Probaili

# %%
sns.countplot(x=df['Product'])
# Out:
# <Axes: xlabel='Product', ylabel='count'>

# %%
df['Age'].min(),df['Age'].max()
# Out:
# (18, 50)

# %% [markdown]
# *   Age of the users ranges from 18 till 50, can be concluded that this age group people are more health and fitness conscious.
# *   Targetted audience can be in the above mentioned age group (18-55)

# %%
df['Gender'].value_counts()
df['Gender'].value_counts(normalize=True)
# Out:
# Gender
# Male      0.577778
# Female    0.422222
# Name: proportion, dtype: float64

# %% [markdown]
# *   More men purchase the item than the women
# *   Can be said that men focus more on their fitness than women
# *   Men can more targetted.
# *   More awareness can be created among women about the product's benefits, especially how it supports good fitness and health, so that no of female customers can be enhanced
# *   Probability for men purchasing the item is more than that for a women

# %%
df.groupby(['Product','Gender']).agg(count=('Product', 'count'))
# Out:
#                 count
# Product Gender
# KP281   Female     40
#         Male       40
# KP481   Female     29
#         Male       31
# KP781   Female      7
#         Male       33

# %% [markdown]
# *   KP281 Model is purchased equally among women and men
# *   KP481 is purchased mostly by men, but still considerable amount of women also have purchased the product
# *   KP781 has been mostly purchased by men only, only a few female have purchased this item
# *   The benefits of each model has to be given more popularity among women.
# *   Comparatively lower number of men purchases the model KP481
# *   Least number of women purchased the model KP781.
#
#
# *   p(kp281/m)=40/104 is Probability of buying the product KP281 for a man
# * P(KP281/Female)=40/76 is the Probability of buying the product KP281 for a women
# * P/(KP481/Male)=31/104 is the Probability of buying the product KP481 for a men
# * P/(KP481/Female)=29/79 is the Probability of buying the product KP481 for a women
# * P/(KP781/Female)=7/79 is the Probability of buying the product KP781 for a women
# * P/(KP781/male)=33/104 is the Probability of buying the product KP781 for a men

# %%
range = [17, 30, 45, 55]
name = ['Young Adults (18-30)', 'Middle Adults (31-45)', 'Older Adults (46-55)']
df['Age_group']=pd.cut(df['Age'],bins=range,labels=name)
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 53    KP281   30    Male         14     Partnered      4        4   46617
# 54    KP281   30    Male         14        Single      3        3   54576
# 113   KP481   30  Female         14        Single      3        3   57987
# 114   KP481   30  Female         13        Single      4        3   46617
# 167   KP781   30  Female         16     Partnered      6        5   90886
# 168   KP781   30    Male         18     Partnered      5        4  103336
# 169   KP781   30    Male         18     Partnered      5        5   99601
#
#      Miles             Age_group
# 53     141  Young Adults (18-30)
# 54      85  Young Adults (18-30)
# 113     74  Young Adults (18-30)
# 114    106  Young Adults (18-30)
# 167    280  Young Adults (18-30)
# 168    160  Young Adults (18-30)
# 169    150  Young Adults (18-30)

# %% [markdown]
# Age column has been divided into three different groups, from the range 18 to 55 as 'Young Adults (18-30)', 'Middle Adults (31-45)', 'Older Adults (46-55)'.

# %%
df[['Age_group','Gender']].value_counts(normalize=True)
# Out:
# Age_group              Gender
# Young Adults (18-30)   Male      0.383333
#                        Female    0.283333
# Middle Adults (31-45)  Male      0.172222
#                        Female    0.127778
# Older Adults (46-55)   Male      0.022222
#                        Female    0.011111
# Name: proportion, dtype: float64

# %% [markdown]
# *   Young adults buy more products as compared to rest of the groups
# *   Fewer purchases have been made by the older Adults
# * Probability for purchasing item is more for Young Adults
# In this age group men buy it more than females do
# *   Least number of products have been purchased by the older adult women and men as 2 and 3 respectively

# %%
sns.boxplot(x=df['Age'])
# Out:
# <Axes: xlabel='Age'>

# %% [markdown]
# * Boxplot for the data age is shown.
# * most of the customers are in the age 23-35
# * only very less number of people having age greater than 45 and less than 23 buy the product.

# %%
low = df['Age'].quantile(0.05)
high = df['Age'].quantile(0.95)
df['Age'] = np.clip(df['Age'], low, high)

# %%
df.groupby(['Product','Age_group']).agg(count=('Product','count'))
# Out:
# /tmp/ipython-input-3426489748.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['Product','Age_group']).agg(count=('Product','count'))
#                                count
# Product Age_group
# KP281   Young Adults (18-30)      55
#         Middle Adults (31-45)     22
#         Older Adults (46-55)       3
# KP481   Young Adults (18-30)      35
#         Middle Adults (31-45)     24
#         Older Adults (46-55)       1
# KP781   Young Adults (18-30)      30
#         Middle Adults (31-45)      8
#         Older Adults (46-55)       2

# %% [markdown]
# *   People in the young adult age purchase more product as compared to other age groups.
# *   Business can be incresed if the product is focused mostly on Young and middle age adults.
# *   However, older adults should be given awareness of health benfits of these products
# *  Probability of buying KP281 for Young People is 55/120
# *  Probability of buying KP481 for Young People is 35/120
# * Probability of buying KP781 for Young People is 30/120
#
# *   Probability of buying KP281 for Middle People is 22/54
# *   Probability of buying KP481 for Middle People is 24/54
# *  Probability of buying KP781 for Middle People is 8/54
#
# *   Probability of buying KP281 for Older People is 3/6
# *   Probability of buying KP481 for Older People is 1/6
# * Probability of buying KP281 for Older People is 2/6
#
# * 50% of older people prefer to buy KP281 model
# * Young people mostly purchase the KP281 model
# * Middle age people prefer to buy KP281 as well as KP481

# %%
df['MaritalStatus'].value_counts(normalize=True)
# Out:
# MaritalStatus
# Partnered    0.594444
# Single       0.405556
# Name: proportion, dtype: float64

# %% [markdown]
# Partnered people mostly prefer to buy the tredmill over the Single people eventhough the percentages are around 60% and 40% respectively

# %%
df['Income'].min(),df['Income'].max()
# Out:
# (29562, 104581)

# %%
income_range = [29561, 54568, 79574, 104581]
income_label= ['Lower Income', 'Average Income', 'High Income']
df['Income_group']=pd.cut(df['Income'],bins=income_range,labels=income_label)

# %%
sns.boxplot(df['Income'])
# Out:
# <Axes: ylabel='Income'>

# %% [markdown]
# * Mostly people with income between 45000 $ and 60000 $ purchase the tredmill more than other income people

# %%
df.groupby(['Product','Income_group']).agg(count=('Product','count'))
# Out:
# /tmp/ipython-input-3451729001.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['Product','Income_group']).agg(count=('Product','count'))
#                         count
# Product Income_group
# KP281   Lower Income       62
#         Average Income     18
#         High Income         0
# KP481   Lower Income       47
#         Average Income     13
#         High Income         0
# KP781   Lower Income        8
#         Average Income     13
#         High Income        19

# %% [markdown]
# *   Probability of buying KP281 for Lower Income people is 62/117
# *   Probability of buying KP481 for Lower Income people is 47/117
# *   Probability of buying KP781 for Lower Income people is 8/117
#
# *  Probability of buying KP281 for Avergage Income people is 18/44
# *  Probability of buying KP481 for Avergage Income people is 13/44
# *  Probability of buying KP781 for Avergage Income people is 13/44
#
# *  Probability of buying KP281 and KP481 for High Income people is 0
# *  Probability of buying KP781 for High Income people is 1
#
# * People having lower income mostly prefer to have the KP281 model and only fewer in the category prefer for KP781
# * Average income people also prefer for the KP281 model (about 40%). Eqaul number of people prefer for 481 and 781 model (30%).
# * HIgher Income people only prefer for the 781 model. None of purchased either 281 or 481.
# * From this analysis it is well clear that KP281 and KP481 are mostly preferred by the Lower and average income people and KP781 is preferred by the high income people.

# %%
low = df['Income'].quantile(0.05)
high = df['Income'].quantile(0.95)
df['Income'] = np.clip(df['Income'], low, high)

# %%
fit_bins = [0, 2, 3, 5]
fit_labels = ['Poor Fitness', 'Average Fitness', 'Excellent Fitness']
df['Fit_group']=pd.cut(df['Fitness'],bins=fit_bins,labels=fit_labels)
df['Fit_group'].value_counts(normalize=True)
# Out:
# Fit_group
# Average Fitness      0.538889
# Excellent Fitness    0.305556
# Poor Fitness         0.155556
# Name: proportion, dtype: float64

# %% [markdown]
# *   People with avergae fitness have purchased the tredmill over other fit people
# *   Product is least probable to be bought by the poor fitness peole
# * Probability for Excellent Fit people to by the product is around 30%

# %%
df.groupby(['Product','Fit_group']).agg(count=('Product','count'))
# Out:
# /tmp/ipython-input-2846173435.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['Product','Fit_group']).agg(count=('Product','count'))
#                            count
# Product Fit_group
# KP281   Poor Fitness          15
#         Average Fitness       54
#         Excellent Fitness     11
# KP481   Poor Fitness          13
#         Average Fitness       39
#         Excellent Fitness      8
# KP781   Poor Fitness           0
#         Average Fitness        4
#         Excellent Fitness     36

# %% [markdown]
# *  Probability of buying KP281 for Poor fit people is 15/28
# *  Probability of buying KP481 for Poor fit people is 13/28
# *  Probability of buying KP781 for Poor fit people is 0
#
# *  Probability of buying KP281 for Average fit people is 54/97
# *  Probability of buying KP481 for Average fit people is 39/97
# *  Probability of buying KP781 for Average fit people is 4/97
#
# *  Probability of buying KP281 for Excellent fit people is 11/55
# *  Probability of buying KP481 for Excellent fit people is 8/55
# *  Probability of buying KP781 for Excellent fit people is 36/55
#
# * Model KP281 is mostly preferred by the poor fit and average fit people
# * Excellent fit people highly prefer for the KP781 model
# * KP481 is purchased by the average fit people and poor fit people as well.
# *  KP781 should be advertised among  poor fit and average fit people.

# %%
df.groupby(['Product','Usage']).agg(count=('Product','count'))
# Out:
#                count
# Product Usage
# KP281   2         19
#         3         37
#         4         22
#         5          2
# KP481   2         14
#         3         31
#         4         12
#         5          3
# KP781   3          1
#         4         18
#         5         12
#         6          7
#         7          2

# %% [markdown]
# * Large number of people use the product moslty 3 days a week and most of them prefer for the KP281 and KP481 model.
# * Only a fewer number of people (2) use the product for 7 days a week and they use KP781 model

# %%
df.groupby(['Product','Fit_group', 'Gender']).agg(count=('Product','count'))
# Out:
# /tmp/ipython-input-977692722.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['Product','Fit_group', 'Gender']).agg(count=('Product','count'))
#                                   count
# Product Fit_group         Gender
# KP281   Poor Fitness      Female     10
#                           Male        5
#         Average Fitness   Female     26
#                           Male       28
#         Excellent Fitness Female      4
#                           Male        7
# KP481   Poor Fitness      Female      7
#                           Male        6
#         Average Fitness   Female     18
#                           Male       21
#         Excellent Fitness Female      4
#                           Male        4
# KP781   Poor Fitness      Female      0
# ...

# %% [markdown]
# * KP781 is model used moslty by the excellent fit and higher income people (otherwise the excellent fit people are the one having higher income)
# *  Most of the women, who purchased the product are having average fitness and they bought moslty KP281
# * Men and women having excellent fitness bought KP781 as compared to other model
# * Excellent fit people are preferring KP781 model over other models
# * NOne of the poor fit people bought KP781
# * Poor fit and average fit people have to be given awareness about the advantage of using KP781.
